# %%
employee = {

"name": "Amit",

"department": "Engineering",

"skills": {

"language": "Python",

"database": "PostgreSQL",

"cloud": "AWS"

},

"salary": 80000

}

# %% [markdown]
# Print employee name
#
# Print department
#
# Print complete skills dictionary
#
# Print programming language
#
# Print database
#
# Print cloud technology

# %%
print(employee["name"])
print(employee["department"])
print(employee["skills"])
print(employee["skills"]["language"])
print(employee["skills"]["database"])
print(employee["skills"]["cloud"])
# Out:
# Amit
# Engineering
# {'language': 'Python', 'database': 'PostgreSQL', 'cloud': 'AWS'}
# Python
# PostgreSQL
# AWS

# %%
#Change "Python" to "Python + JavaScript"

employee["skills"]["language"] = "Python + JavaScript"

# %%
print(employee["skills"])
# Out:
# {'language': 'Python + JavaScript', 'database': 'PostgreSQL', 'cloud': 'AWS'}

# %%
#Change salary

employee["salary"] = 100000

# %%
print(employee["salary"])
# Out:
# 100000

# %%
# Add "experience": 3

employee.update({"experience": 3})

# %%
print(employee)
# Out:
# {'name': 'Amit', 'department': 'Engineering', 'skills': {'language': 'Python + JavaScript', 'database': 'PostgreSQL', 'cloud': 'AWS'}, 'salary': 100000, 'experience': 3}

# %%
#Add another skill under the skills dictionary

employee["skills"]["IAC"] = "terraform"

# %%
print(employee)
# Out:
# {'name': 'Amit', 'department': 'Engineering', 'skills': {'language': 'Python + JavaScript', 'database': 'PostgreSQL', 'cloud': 'AWS', 'IAC': 'terraform'}, 'salary': 100000, 'experience': 3}

# %% [markdown]
# Explain how nested dictionaries are accessed.
#
# Nested dictionaries is a dictionary that contains another dictionaries inside it.
#
# To access the values in dictionary we call the variable name and key name, unlike other data type we use index. But in dictionary we use key name
# ex : employee['name']
#
# To access the values in nested dictionaries, need to call the nested dictionary first and then key value inside the nested dictionary.
# ex : employee["skills"]["IAC"]
