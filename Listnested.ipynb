# %%
lis= [2, 3.5, "star", True]

# %%
ll = [2, 3.5, "star", True , [5, "super", False]]

# %%
students = [ ["Rahul", 21, "Python"],["Priya", 22, "Data Science"],["Aman", 20, "Machine Learning"] ]

# %%
print(students)
# Out:
# [['Rahul', 21, 'Python'], ['Priya', 22, 'Data Science'], ['Aman', 20, 'Machine Learning']]

# %%
print(lis[1])
# Out:
# 3.5

# %%
print(students[0][1])
# Out:
# 21

# %%
print(students[1][0])
# Out:
# Priya

# %%
print(students[2][2])
# Out:
# Machine Learning

# %%
print(students[1])
# Out:
# ['Priya', 22, 'Data Science']

# %%
students[0][2] = "AI"

# %%
print(students[0])
# Out:
# ['Rahul', 21, 'AI']

# %%
students.append(["ski", 32, "Devops"])

# %%
print(students)
# Out:
# [['Rahul', 21, 'AI'], ['Priya', 22, 'Data Science'], ['Aman', 20, 'Machine Learning'], ['ski', 32, 'Devops']]

# %%
students.remove(['Priya', 22, 'Data Science'])

# %%
print(students)
# Out:
# [['Rahul', 21, 'AI'], ['Aman', 20, 'Machine Learning'], ['ski', 32, 'Devops']]
