# %%
sts = "python programming for data science"

print (sts)
# Out:
# python programming for data science

# %%
print(sts[0])
# Out:
# p

# %%
print(sts[-1])
# Out:
# e

# %%
print(sts[-3])
# Out:
# n

# %%
print(sts[0:6])
# Out:
# python

# %%
print(sts[-7::])
# Out:
# science

# %%
print(sts[::-1])
# Out:
# ecneics atad rof gnimmargorp nohtyp

# %%
sts.upper()
# Out:
# 'PYTHON PROGRAMMING FOR DATA SCIENCE'

# %%
sts.lower()
# Out:
# 'python programming for data science'

# %%
sts.title()
# Out:
# 'Python Programming For Data Science'

# %%
sts.count("e")
# Out:
# 2

# %%
sts.find("for")
# Out:
# 19

# %%
sts.replace("python" , "Advcaned python")
# Out:
# 'Advcaned python programming for data science'

# %%
sts.split()
# Out:
# ['python', 'programming', 'for', 'data', 'science']
