# %%
a = 100

print(a)
# Out:
# 100

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
b = 12

print(type(b))
# Out:
# <class 'int'>

# %%
a = 120

# %%
print(a)
# Out:
# 120

# %%
a = "100"
print(type(a))
# Out:
# <class 'str'>

# %%
e ='Skilabs'
print(e)
print(type(e))
# Out:
# Skilabs
# <class 'str'>

# %%
f = 12.5
print(type(f))
# Out:
# <class 'float'>

# %%
r = 100.5
print(type(r))
# Out:
# <class 'float'>

# %%
f ="12.5"
print(type(f))
# Out:
# <class 'str'>

# %%
u = True
print(type(u))
# Out:
# <class 'bool'>

# %%
v = False
print(type(v))
# Out:
# <class 'bool'>

# %%
h = u-v
print(h)
print(type(h))
# Out:
# 1
# <class 'int'>

# %%
l = [2, "ski", 3.3, True, [5,8,"lab"]]

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
ll = [99, "hi all", 106.5, False]
print(type(ll))
# Out:
# <class 'list'>

# %%
t = (8,"super", True, 33.9, ["name", 30, False])
print(type(t))
# Out:
# <class 'tuple'>

# %%
st = {44, 5, 8,"star", 9.5, 5}
print(st)
print(type(st))
# Out:
# {5, 8, 9.5, 44, 'star'}
# <class 'set'>

# %%
Alpha = {"name": "ski"}
print(type(Alpha))
# Out:
# <class 'dict'>

# %%
beta ={"age": 32, "exp": 10.5 , "like_python" : True , "sports" : {"cricket": "Batsmen", "football" : "defender", "Marathon": 10}}
print(type(beta))
# Out:
# <class 'dict'>

# %%
a = int("100")
print(type(a))
# Out:
# <class 'int'>

# %%
b = str(a)
print(type(b))
# Out:
# <class 'str'>

# %%
c = "True"

# %%
d = bool(c)
print(type(d))
# Out:
# <class 'bool'>

# %%
l = [4, "rays", 9.8]

# %%
t = tuple(l)
print(type(t))
# Out:
# <class 'tuple'>

# %%
li= list((7,99,4.5, "hero"))

# %%
print(type(li))
print(li)
# Out:
# <class 'list'>
# [7, 99, 4.5, 'hero']

# %%
ll = [55, 900, 87.5, "True", 900, 11, 55]

# %%
sa = set(ll)
print(type(sa))
print(sa)
# Out:
# <class 'set'>
# {900, 11, 'True', 55, 87.5}
