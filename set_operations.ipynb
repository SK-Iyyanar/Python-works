# %%
python_students = {"Rahul", "Aman", "Priya", "Karan", "Neha"}

java_students = {"Priya", "Karan", "Rohit", "Simran"}

# %%
#Print both sets

print(python_students)
print(java_students)
# Out:
# {'Karan', 'Neha', 'Rahul', 'Aman', 'Priya'}
# {'Priya', 'Karan', 'Simran', 'Rohit'}

# %%
#Find students learning either Python or Java

python_students.union(java_students)
# Out:
# {'Aman', 'Karan', 'Neha', 'Priya', 'Rahul', 'Rohit', 'Simran'}

# %%
#Find students learning both

python_students.intersection(java_students)
# Out:
# {'Karan', 'Priya'}

# %%
#Find students learning only Python

python_students.difference(java_students)
# Out:
# {'Aman', 'Neha', 'Rahul'}

# %%
#Find students learning only Java

java_students.difference(python_students)
# Out:
# {'Rohit', 'Simran'}

# %%
#Find students belonging to exactly one group

python_students.symmetric_difference(java_students)
# Out:
# {'Aman', 'Neha', 'Rahul', 'Rohit', 'Simran'}

# %%
#Add a new student

python_students.add("Rambo")
java_students.add("pinkman")
print(python_students)
print(java_students)
# Out:
# {'Karan', 'Neha', 'Rahul', 'Aman', 'Priya', 'Rambo'}
# {'Rohit', 'Simran', 'pinkman', 'Karan', 'Priya'}

# %%
#Remove a student

python_students.remove("Neha")
java_students.remove("Simran")
print(python_students)
print(java_students)
# Out:
# {'Karan', 'Rahul', 'Aman', 'Priya', 'Rambo'}
# {'Rohit', 'pinkman', 'Karan', 'Priya'}

# %%
#Demonstrate discard()

python_students.discard("Aman")
print(python_students)
# Out:
# {'Karan', 'Rahul', 'Priya', 'Rambo'}

# %%
java_students.discard("Priya")
print(java_students)
# Out:
# {'Rohit', 'pinkman', 'Karan'}
