# %%
technologies = ("Python", "Java", "Python", "C++", "JavaScript", "Python")

# %%
print(technologies)
# Out:
# ('Python', 'Java', 'Python', 'C++', 'JavaScript', 'Python')

# %%
print(type(technologies))
# Out:
# <class 'tuple'>

# %%
print(technologies[0])
# Out:
# Python

# %%
print(technologies[-1])
# Out:
# Python

# %%
print(technologies[0:3])
# Out:
# ('Python', 'Java', 'Python')

# %%
tech.count("Python")
# Out:
# 3

# %%
tech.index("C++")
# Out:
# 3

# %%
print(len(technologies))
# Out:
# 6

# %%
tech_list = list(technologies)
print(type(tech_list))
print(tech_list)
# Out:
# <class 'list'>
# ['Python', 'Java', 'Python', 'C++', 'JavaScript', 'Python']

# %%
tech_list.append("Go")

# %%
print(tech_list)
# Out:
# ['Python', 'Java', 'Python', 'C++', 'JavaScript', 'Python', 'Go']

# %%
tech_set = tuple(tech_list)
print(type(tech_set))
print(tech_set)
# Out:
# <class 'tuple'>
# ('Python', 'Java', 'Python', 'C++', 'JavaScript', 'Python', 'Go')

# %% [markdown]
# Explain why tuples are called immutable.
#
# Immutability means once a value is created in tuple it cannot be chnaged.
# like the value can't be replaced or deleted
# Also new values can't be added to tuples too. Thats why its called as Immutable.
