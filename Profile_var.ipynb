# %%
Name = "Ski"

Age =32

City = "Kl Town"

College_name= "AAIST"

Current_learning_topic = "Python"

Years_of_experience = 10.7

Whether_you_like_Python= True

Your_expected_salary_after_learning_Python = 20000

# %%
print("Name: ", Name)
print("Age:",Age)
print("City:",City)
print("College_name:",College_name)
print("Current_learning_topic:",Current_learning_topic)
print("Years_of_experience:",Years_of_experience)
print("Whether_you_like_Python:",Whether_you_like_Python)
print("Your_expected_salary_after_learning_Python:",Your_expected_salary_after_learning_Python)
# Out:
# Name:  Ski
# Age: 32
# City: Kl Town
# College_name: AAIST
# Current_learning_topic: Python
# Years_of_experience: 10.7
# Whether_you_like_Python: True
# Your_expected_salary_after_learning_Python: 20000

# %%
print(type(Name))
print(type(Age))
print(type(City))
print(type(College_name))
print(type(Current_learning_topic))
print(type(Years_of_experience))
print(type(Whether_you_like_Python))
print(type(Your_expected_salary_after_learning_Python))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# <class 'int'>
