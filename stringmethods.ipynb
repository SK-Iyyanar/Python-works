# %%
msg ="  Welcome all to the python class"

# %%
msg.strip()
# Out:
# 'Welcome all to the python class'

# %%
msg.upper()
# Out:
# '  WELCOME ALL TO THE PYTHON CLASS  '

# %%
msg.lower()
# Out:
# '  welcome all to the python class  '

# %%
msg.title()
# Out:
# '  Welcome All To The Python Class  '

# %%
msg.replace( "class" , "Session")
# Out:
# '  Welcome all to the python Session  '

# %%
msg.find("the")
# Out:
# 17

# %%
msg.count("o")
# Out:
# 3

# %%
msg.split()
# Out:
# ['Welcome', 'all', 'to', 'the', 'python', 'class']

# %%
msg.startswith("Welcome" )
# Out:
# False

# %%
msg.startswith (" ")
# Out:
# True

# %%
msg.endswith ("class")
# Out:
# True
