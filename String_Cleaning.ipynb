# %%
m = " Welcome To Python Programming Class "

# %%
m.strip()
# Out:
# 'Welcome To Python Programming Class'

# %%
me = ' '.join(m.split())
print(m)
print(me)
# Out:
#  Welcome To Python Programming Class
# Welcome To Python Programming Class

# %%
print(me)
# Out:
# Welcome To Python Programming Class

# %%
m.lower()
# Out:
# ' welcome to python programming class '

# %%
m.upper()
# Out:
# ' WELCOME TO PYTHON PROGRAMMING CLASS '

# %%
m.replace ("Python", "Advanced Python")
# Out:
# ' Welcome To Advanced Python Programming Class '

# %%
m.find("Programming")
# Out:
# 19

# %%
m.split()
# Out:
# ['Welcome', 'To', 'Python', 'Programming', 'Class']

# %%
m.count("o")
# Out:
# 4

# %%
# Check if the string starts with 'Welcome'
does_start_with_welcome = m.startswith("Welcome")
print(f"Does the string start with 'Welcome'? {does_start_with_welcome}")
# Out:
# Does the string start with 'Welcome'? False

# %%
# Check if the string ends with 'Class'
does_end_with_class = m.endswith("Class")
print(f"Does the string end with 'Class'? {does_end_with_class}")
# Out:
# Does the string end with 'Class'? False

# %%
me.startswith("Welcome")
# Out:
# True

# %%
m.endswith("Class")
# Out:
# False
