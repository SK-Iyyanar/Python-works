# %%
cart = ["Laptop", "Mouse", "Keyboard", "Monitor", "Headphones"]
print(cart)
# Out:
# ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Headphones']

# %%
print(cart[0])
# Out:
# Laptop

# %%
print(cart[-1])
# Out:
# Headphones

# %%
cart.append("webcam")
print(cart)
# Out:
# ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Headphones', 'webcam']

# %%
cart.remove("Mouse")

# %%
print(cart)
# Out:
# ['Laptop', 'Keyboard', 'Monitor', 'Headphones', 'webcam']

# %%
cart.insert(2, "Usb Hub")

# %%
print(cart)
# Out:
# ['Laptop', 'Keyboard', 'Usb Hub', 'Monitor', 'Headphones', 'webcam']

# %%
cart.pop()
print(cart)
# Out:
# ['Laptop', 'Keyboard', 'Usb Hub', 'Monitor', 'Headphones']

# %%
cart.index("Monitor")
# Out:
# 3

# %%
cart.count("Laptop")
# Out:
# 1

# %%
new_cart = cart.copy()

# %%
print(new_cart)
print(cart)
# Out:
# ['Laptop', 'Keyboard', 'Usb Hub', 'Monitor', 'Headphones']
# ['Laptop', 'Keyboard', 'Usb Hub', 'Monitor', 'Headphones']

# %%
cart.reverse()
print(cart)
# Out:
# ['Headphones', 'Monitor', 'Usb Hub', 'Keyboard', 'Laptop']

# %%
cart.sort()
print(cart)
# Out:
# ['Headphones', 'Keyboard', 'Laptop', 'Monitor', 'Usb Hub']
